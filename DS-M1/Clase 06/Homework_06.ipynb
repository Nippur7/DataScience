# %% [markdown]
# # Práctica Clase 6

# %% [markdown]
# 1) Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash".<br>
# Consideraciones: Se puede utilizar la función provista.

# %%
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
print(hash_function('pato'))
print(hash_function('tapo'))
# Out:
# 1807
# 1799

# %%
import pandas as pd

# %%
df = pd.read_csv('Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1',thousands='.')
df
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 0                ABW           Aruba  América Latina y Caribe  1960       NaN
# 1                ABW           Aruba  América Latina y Caribe  1961       NaN
# 2                ABW           Aruba  América Latina y Caribe  1962       NaN
# 3                ABW           Aruba  América Latina y Caribe  1963       NaN
# 4                ABW           Aruba  América Latina y Caribe  1964       NaN
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007   9732.22
# 11123            ZWE        Zimbabue      África subsahariana  2008   7682.37
# 11124            ZWE        Zimbabue      África subsahariana  2009   8239.75
# 11125            ZWE        Zimbabue      África subsahariana  2010   9028.15
# 11126            ZWE        Zimbabue      África subsahariana  2011   9860.56
#
# ...

# %%
df.dropna(inplace=True)
df.info
# Out:
# <bound method DataFrame.info of       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26               ABW           Aruba  América Latina y Caribe  1986   179.683
# 27               ABW           Aruba  América Latina y Caribe  1987   447.374
# 28               ABW           Aruba  América Latina y Caribe  1988   612.389
# 29               ABW           Aruba  América Latina y Caribe  1989   649.059
# 30               ABW           Aruba  América Latina y Caribe  1990  1840.830
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9732.220
# 11123            ZWE        Zimbabue      África subsahariana  2008  7682.370
# 11124            ZWE        Zimbabue      África subsahariana  2009  8239.750
# 11125            ZWE        Zimbabue      África subsahariana  2010  9028.150
# 11126            ZWE        Zimbabue      África subsahariana  2011  9860.560
#
# ...

# %%
df.rename(columns={'Código de país': 'cod_pais','Nombre del país':'nom_pais','CO2 (kt)':'emision_co2','CO2 per cápita (toneladas métricas':'emisiones_co2_percapita'}, inplace=True)

# %%
df['clave_hash'] = df['cod_pais'].apply(hash_function)
df
# Out:
#       cod_pais  nom_pais                   Región   Año  emision_co2  \
# 26         ABW     Aruba  América Latina y Caribe  1986      179.683
# 27         ABW     Aruba  América Latina y Caribe  1987      447.374
# 28         ABW     Aruba  América Latina y Caribe  1988      612.389
# 29         ABW     Aruba  América Latina y Caribe  1989      649.059
# 30         ABW     Aruba  América Latina y Caribe  1990     1840.830
# ...        ...       ...                      ...   ...          ...
# 11122      ZWE  Zimbabue      África subsahariana  2007     9732.220
# 11123      ZWE  Zimbabue      África subsahariana  2008     7682.370
# 11124      ZWE  Zimbabue      África subsahariana  2009     8239.750
# 11125      ZWE  Zimbabue      África subsahariana  2010     9028.150
# 11126      ZWE  Zimbabue      África subsahariana  2011     9860.560
#
#        CO2 per cápita (toneladas métricas)  clave_hash
# 26                                2.868319         910
# ...

# %% [markdown]
# resuelto por papi

# %%
#df_copia = df.dropna(subset=['CO2 (kt)'])
#df_copia['Clave_Hash'] = df_copia['Código de país'].apply(hash_function)
#df_copia
#df_copia = df_copia.sort_values(by='CO2 (kt)', ascending=False)
df_copia = df.sort_values(by='CO2 (kt)', ascending=False)
df_copia = df_copia.drop_duplicates(subset=['Código de país'])
df_copia

# %%
df_copia = df_copia.dropna(subset=['CO2 (kt)'])
df_copia['Clave_Hash'] = df_copia['Código de país'].apply(hash_function)
df_copia
# Out:
#       Código de país  Nombre del país                           Región   Año  \
# 4347             HTI            Haití          América Latina y Caribe  1991
# 7305             NER            Níger              África subsahariana  1985
# 873              BFA     Burkina Faso              África subsahariana  2001
# 6679             MLT            Malta  Oriente Medio y Norte de África  1983
# 7748             PAN           Panamá          América Latina y Caribe  1960
# ...              ...              ...                              ...   ...
# 8456             RUS            Rusia            Europa y Asia Central  1992
# 9927             TLS   Timor Oriental    Asia Oriental y Asia-Pacífico  2008
# 9303             SVN        Eslovenia            Europa y Asia Central  2008
# 2528             CZE  República Checa            Europa y Asia Central  1992
# 10493            UZB       Uzbekistán            Europa y Asia Central  2002
#
# ...

# %% [markdown]
# 2. A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9029 entries, 26 to 11126
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   cod_pais                             9029 non-null   object
#  1   nom_pais                             9029 non-null   object
#  2   Región                               9029 non-null   object
#  3   Año                                  9029 non-null   int64
#  4   emision_co2                          9029 non-null   float64
#  5   CO2 per cápita (toneladas métricas)  9029 non-null   float64
#  6   clave_hash                           9029 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 564.3+ KB

# %%
df_valores_unicos = df[['clave_hash','cod_pais','nom_pais','Región']].drop_duplicates().reset_index()
df.drop(['cod_pais','nom_pais','Región'], inplace=True, axis=1)
df_valores_unicos
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\tonym\OneDrive\Documentos\Henry\Data Science\Clase 06\Homework_06.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000017?line=0'>1</a> df_valores_unicos = df[['clave_hash','cod_pais','nom_pais','Región']].drop_duplicates().reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000017?line=1'>2</a> df.drop(['cod_pais','nom_pais','Región'], inplace=True, axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000017?line=2'>3</a> df_valores_unicos
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9029 entries, 26 to 11126
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Año                                  9029 non-null   int64
#  1   emision_co2                          9029 non-null   float64
#  2   CO2 per cápita (toneladas métricas)  9029 non-null   float64
#  3   clave_hash                           9029 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 352.7 KB

# %%
df_valores_unicos['']
df_valores_unicos['clave_hash'] == 910
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# Name: clave_hash, Length: 199, dtype: bool

# %% [markdown]
# usar merge, ejercicio para investigar

# %% [markdown]
# resuelto por papi

# %%
df_2 = df_copia.loc[:,['Clave_Hash','Código de país','Nombre del país','Región']]
#df_2.info
df_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\tonym\OneDrive\Documentos\Henry\Data Science\Clase 06\Homework_06.ipynb Cell 16' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000009?line=0'>1</a> df_2 = df_copia.loc[:,['Clave_Hash','Código de país','Nombre del país','Región']]
#       <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000009?line=1'>2</a> #df_2.info
#       <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/Clase%2006/Homework_06.ipynb#ch0000009?line=2'>3</a> df_2
#
# NameError: name 'df_copia' is not defined
