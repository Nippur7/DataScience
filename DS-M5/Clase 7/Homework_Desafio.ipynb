# %% [markdown]
# **Fractales**
#
# Un fractal es un objeto geométrico en el que se repite el mismo patrón a diferentes escalas y con diferente orientación. La expresión fractal viene del latín fractus, que significa fracturado, roto, irregular.
#
# Se conoce como fractal a las imágenes obtenidas mediante la representación gráfica de una función matemática iterada. La cuál, es una expresión que permite calcular una variable dependiente del valor de otras, o del suyo propio en un proceso iterativo.
#
# Lo más común en la naturaleza (montañas, nubes, costas, etc.) es la irregularidad, no está formado por líneas o superficies lisas.
#
# El conjunto de Mandelbrot es el más estudiado de los fractales. Se conoce así en honor al matemático Benoît Mandelbrot (1924-2010), que investigó sobre él en los años setenta.
#
# Este conjunto se define en el plano complejo fijando un número complejo c cualquiera. A partir de c, se construye una sucesión por recursión:
#
# <img alt="Formula Conjunto M" title="Formula Conjunto de Mandelbrot" src="Formula_M.png">
#
# Si esta sucesión queda acotada, entonces se dice que c pertenece al conjunto de Mandelbrot, y si no, queda excluido del mismo.
#
# https://www.fractalus.com/kerry/articles/area/mandelbrot-area.html

# %% [markdown]
# **Se crea la funcion de iteración:**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_iter(c:complex, thresh:int =4, max_steps:int =25) -> int:
    # Z_(n) = (Z_(n-1))^2 + c
    # Z_(0) = c
    z=c
    i=1
    while i<max_steps and (z*z.conjugate()).real<thresh:
        z=z*z +c
        i+=1
    return i

# %% [markdown]
# **Se genera la imagen del Conjunto M**
#
# El parametro dim contiene:
# 1. La cantidad de pixeles por lados, es decir, para una imagen de 10x10, su valor será 10. Las imagenes seran cuadrados.
# 2. Al mostrar la imagen, vamos a poder hacerlo completamente, o sobre un sector de la misma, X e Y definen el punto inicial
# 3. El valor de D, será el rango a mostrar de la imagen
# 4. Max_Steps va a definir, la cantidad máxima de iteraciones para establecer si un punto, esta o no, dentro del conjunto.

# %%
def plotter(dim, thresh, max_steps=25):
    n = dim[0]
    xi = dim[1]
    yi = dim[2]
    d = dim[3]
    mx = 2.48 / (n-1)
    my = 2.26 / (n-1)
    mapper = lambda x,y: (mx*x - 2, my*y - 1.13)
    
    img=np.full((d,d), 255)
    for x in range(xi, (xi + d)):
        for y in range(yi, (yi + d)):
            it = get_iter(complex(*mapper(x,y)), thresh=thresh, max_steps=max_steps)
            img[(y-yi)][(x-xi)] = 255 - it
    return img

# %% [markdown]
# Probamos sobre un modelo de 100 x 100, mostrandolo por completo:

# %%
n= [100, 0, 0, 100]
img = plotter(n, thresh=4, max_steps=30)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 99.5, 99.5, -0.5)

# %% [markdown]
# Probamos sobre un modelo de 100 x 100, mostrando solo el cuadrante superior derecho:

# %%
n= [100, 50, 0, 50] #Nos movemos 50 en x (de izquierda a derecha) y 0 en Y (de arriba a abajo)
img = plotter(n, thresh=4, max_steps=30)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 49.5, 49.5, -0.5)

# %% [markdown]
# Generamos la visualización de los 4 cuadrantes:

# %%
import math 
plt.figure(figsize = (1000,1000))
detalle = 2000
sectores = 4 #Debe ser siempre divisible por 4
lado = math.sqrt(sectores)
delta = int(detalle / lado)
sec = np.arange(0, detalle, delta)

# %%
for i in range(sectores):
    plt.subplot(int(lado),int(lado),i+1)
    
    si = int(i/lado)
    sj = int(i%lado)
    
    n= [detalle, sec[sj], sec[si], delta]
       
    img = plotter(n, thresh=4, max_steps=20)
    
    #print('Sector: ' + str(i))
    #print('Fila: ' + str(sec[si]))
    #print('Columna: ' + str(sec[sj])) 
        
    plt.title('Sector: ' + str(i))
    plt.imshow(img, cmap="plasma")
    plt.axis("off")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Podemos enfocarnos en mayor nivel de detalle, por ejemplo el cuadrante superior derecho

# %%
n= [4000, 2000, 0, 2000]
img = plotter(n, thresh=4, max_steps=40)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 1999.5, 1999.5, -0.5)

# %% [markdown]
# Nuevamente, al cuadrante superior derecho

# %%
n= [8000, 6000, 0, 2000]
img = plotter(n, thresh=4, max_steps=40)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 1999.5, 1999.5, -0.5)

# %% [markdown]
# Una vez mas, pero ahora al cuadrante inferior derecho

# %%
n= [16000, 14000, 2000, 2000]
img = plotter(n, thresh=4, max_steps=40)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 1999.5, 1999.5, -0.5)

# %% [markdown]
# Una vez mas, pero ahora al cuadrante inferior derecho

# %%
n= [32000, 30000, 6000, 2000]
img = plotter(n, thresh=4, max_steps=40)
plt.imshow(img, cmap="plasma")
plt.axis("on")
# Out:
# (-0.5, 1999.5, 1999.5, -0.5)

# %% [markdown]
# **Ejercicio 1**
#
# CLASES Y OBJETOS
#
# 1. Se necesita crear la clase para el fractal de Mandelbrot
# 2. Los parámetros iniciales serán el largo del lado de todo el recuadro y la cantidad de iteraciones

# %%
class Fractal_ConjuntoM:

    def __init__(self, lado, iteraciones):
        self.Lado = lado
        self.MaxIteraciones = iteraciones
        self.SuperficieTotal = lado * lado
        self.ImagenFractal = np.full((lado,lado), 255)
        self.Thresh = 4
    
    def plotter1(lado, detalle, sectores):
        import math 
        plt.figure(figsize = (lado,lado))
        #detalle = 2000
        #sectores = 4 #Debe ser siempre divisible por 4
        lado = math.sqrt(sectores)
        delta = int(detalle / lado)
        sec = np.arange(0, detalle, delta)
        for i in range(sectores):
            plt.subplot(int(lado),int(lado),i+1)
    
            si = int(i/lado)
            sj = int(i%lado)
    
            n= [detalle, sec[sj], sec[si], delta]
       
            img = plotter(n, thresh=4, max_steps=20)
    
    #print('Sector: ' + str(i))
    #print('Fila: ' + str(sec[si]))
    #print('Columna: ' + str(sec[sj])) 
        
            plt.title('Sector: ' + str(i))
            plt.imshow(img, cmap="plasma")
            plt.axis("off")
    
        plt.tight_layout()
        plt.show()

# %% [markdown]
# 3. A la clase creada, debemos agregar un método que plotee la imagen fractal
# 4. La imagen del fractal debe generarse al instanciar el objeto

# %%
fractal1 = Fractal_ConjuntoM(1000,20)
fractal1.plotter1(2000,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\tonym\OneDrive\Documentos\Henry\Data Science\DS-M5\Clase 7\Homework_Desafio.ipynb Celda 25 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=0'>1</a> fractal1 = Fractal_ConjuntoM(1000,20)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=1'>2</a> fractal1.plotter1(2000,4)
#
# c:\Users\tonym\OneDrive\Documentos\Henry\Data Science\DS-M5\Clase 7\Homework_Desafio.ipynb Celda 25 in Fractal_ConjuntoM.plotter1(dim, detalle, sectores)
#      <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=9'>10</a> def plotter1(dim, detalle, sectores):
#      <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=10'>11</a>     import math
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=11'>12</a>     plt.figure(figsize = (dim,dim))
#      <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=12'>13</a>     #detalle = 2000
#      <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=13'>14</a>     #sectores = 4 #Debe ser siempre divisible por 4
#      <a href='vscode-notebook-cell:/c%3A/Users/tonym/OneDrive/Documentos/Henry/Data%20Science/DS-M5/Clase%207/Homework_Desafio.ipynb#ch0000024?line=14'>15</a>     lado = math.sqrt(sectores)
#
# File c:\Users\tonym\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:808, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     799 if len(allnums) == max_open_warning >= 1:
#     800     _api.warn_external(
#     801         f"More than {max_open_warning} figures have been opened. "
#     802         f"Figures created through the pyplot interface "
#    (...)
#     805         f"warning, see the rcParam `figure.max_open_warning`).",
#     806         RuntimeWarning)
# --> 808 manager = new_figure_manager(
#     809     num, figsize=figsize, dpi=dpi,
#     810     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     811     FigureClass=FigureClass, **kwargs)
#     812 fig = manager.canvas.figure
#     813 if fig_label:
#
# File c:\Users\tonym\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:327, in new_figure_manager(*args, **kwargs)
#     325 """Create a new figure manager instance."""
#     326 _warn_if_gui_out_of_main_thread()
# --> 327 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File c:\Users\tonym\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backend_bases.py:3493, in _Backend.new_figure_manager(cls, num, *args, **kwargs)
#    3491 from matplotlib.figure import Figure
#    3492 fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493 fig = fig_cls(*args, **kwargs)
#    3494 return cls.new_figure_manager_given_figure(num, fig)
#
# File c:\Users\tonym\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\figure.py:2333, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2330 if frameon is None:
#    2331     frameon = mpl.rcParams['figure.frameon']
# -> 2333 if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
#    2334     raise ValueError('figure size must be positive finite not '
#    2335                      f'{figsize}')
#    2336 self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# **Ejercicio 2**
#
# CLASES Y OBJETOS
#
# 1. A la clase creada en el ejercicio 1, debemos agregar un método que plotee la sección solicitada del fractal completo

# %% [markdown]
# **Ejercicio 3**
#
# CLASES Y OBJETOS
#
# 1. A la clase del ejercicio anterior, agregar un método que devuelva la cantidad de pixeles dentro del conjunto sobre el total.
#
# CONSIDERACIONES
#
# 1. Para que un punto se encuentre dentro del fractal, el valor del pixel debe ser igual a 255 menos la cantidad máxima de iteraciones

# %% [markdown]
# 2. Diseñar una forma de visualizar la cantidad de iteraciones por cada pixel del proceso.
